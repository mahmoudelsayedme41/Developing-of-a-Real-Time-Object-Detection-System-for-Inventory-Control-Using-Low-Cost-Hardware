# %%
import os
import zipfile
import cv2
import albumentations as A
import random
from tqdm import tqdm
from collections import defaultdict
import uuid

# ========== 1. Extract Dataset ==========
zip_path = "/content/data.zip"
extract_path = "/content/data_train"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# paths
images_path = os.path.join(extract_path, "images")
labels_path = os.path.join(extract_path, "labels")
final_images_path = os.path.join(extract_path, "balanced/images")
final_labels_path = os.path.join(extract_path, "balanced/labels")

os.makedirs(final_images_path, exist_ok=True)
os.makedirs(final_labels_path, exist_ok=True)

# ========== 2. Define Augmentation Pipeline ==========
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Rotate(limit=20, p=0.5),
    A.Blur(p=0.2),
    A.HueSaturationValue(p=0.3),
    A.CLAHE(p=0.3),
    A.GaussNoise(p=0.3),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=15, p=0.5)
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels'], min_visibility=0.2))

# ========== 3. Organize images by class ==========
class_to_files = defaultdict(list)

for file in os.listdir(images_path):
    if file.endswith((".jpg", ".png", ".jpeg")):
        label_file = os.path.join(labels_path, file.rsplit(".", 1)[0] + ".txt")
        if os.path.exists(label_file):
            with open(label_file, "r") as f:
                lines = f.readlines()
                if len(lines) > 0:
                    cls = int(lines[0].split()[0])  # take first class in label
                    class_to_files[cls].append(file)

# ========== 4. Balance each class to 30 ==========
TARGET = 30

for cls, files in class_to_files.items():
    count = len(files)
    chosen_files = []

    if count >= TARGET:
        chosen_files = random.sample(files, TARGET)
    else:
        chosen_files = files.copy()
        while len(chosen_files) < TARGET:
            chosen_files.append(random.choice(files))

    # Process and save
    for idx, file in enumerate(chosen_files):
        image_file = os.path.join(images_path, file)
        label_file = os.path.join(labels_path, file.rsplit(".", 1)[0] + ".txt")

        image = cv2.imread(image_file)
        h, w = image.shape[:2]

        # Load original bboxes
        bboxes, class_labels = [], []
        with open(label_file, "r") as f:
            for line in f.readlines():
                cls_id, x, y, bw, bh = map(float, line.strip().split())
                bboxes.append([x, y, bw, bh])
                class_labels.append(int(cls_id))

        # If this is an augmented duplicate
        if idx >= count:
            augmented = transform(image=image, bboxes=bboxes, class_labels=class_labels)
            image = augmented["image"]
            bboxes = augmented["bboxes"]
            class_labels = augmented["class_labels"]

        # Save new files
        new_name = f"class{cls}_{idx}_{uuid.uuid4().hex[:6]}.jpg"
        cv2.imwrite(os.path.join(final_images_path, new_name), image)

        new_label = os.path.join(final_labels_path, new_name.replace(".jpg", ".txt"))
        with open(new_label, "w") as f:
            for cls_id, bbox in zip(class_labels, bboxes):
                x, y, bw, bh = bbox
                f.write(f"{cls_id} {x:.6f} {y:.6f} {bw:.6f} {bh:.6f}\n")

# ========== 5. Generate Background Images ==========
BACKGROUND_COUNT = 30  # عدد الصور اللي عايزها بدون داتا

all_images = [f for f in os.listdir(images_path) if f.endswith((".jpg", ".png", ".jpeg"))]

for i in range(BACKGROUND_COUNT):
    file = random.choice(all_images)
    image_file = os.path.join(images_path, file)

    image = cv2.imread(image_file)

    # Apply augmentation عشان التنويع
    augmented = transform(image=image, bboxes=[], class_labels=[])
    image = augmented["image"]

    new_name = f"background_{i}_{uuid.uuid4().hex[:6]}.jpg"
    cv2.imwrite(os.path.join(final_images_path, new_name), image)

    # ليبل فاضي (مفيهوش اي بوكس)
    new_label = os.path.join(final_labels_path, new_name.replace(".jpg", ".txt"))
    open(new_label, "w").close()

print("✅ Balancing finished + Background images created!")
# Out:
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# ✅ Balancing finished + Background images created!

# %%
zip_path = "/content/data2.zip"
extract_path = "/content/data_train2"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# paths
images_path = os.path.join(extract_path, "images")
labels_path = os.path.join(extract_path, "labels")
final_images_path = os.path.join(extract_path, "balanced/images")
final_labels_path = os.path.join(extract_path, "balanced/labels")

os.makedirs(final_images_path, exist_ok=True)
os.makedirs(final_labels_path, exist_ok=True)

# %%
import os
import cv2
import albumentations as A
from tqdm import tqdm

# ===================== Paths =====================
images_path = "/content/data_train2/images"
labels_path = "/content/data_train2/labels"
output_images = "/content/data_train/balanced/images"
output_labels = "/content/data_train/balanced/labels"

os.makedirs(output_images, exist_ok=True)
os.makedirs(output_labels, exist_ok=True)

# ===================== Augmentation Pipeline =====================
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.Rotate(limit=20, p=0.5),
    A.Blur(p=0.2),
    A.HueSaturationValue(p=0.3),
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))

# ===================== Process Each Image =====================
image_files = [f for f in os.listdir(images_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

for file in tqdm(image_files, desc="Processing images"):
    image_path = os.path.join(images_path, file)
    base_name = os.path.splitext(file)[0]
    label_path = os.path.join(labels_path, base_name + ".txt")

    # Read image
    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ Could not read image: {image_path}")
        continue

    # Read labels
    bboxes = []
    class_labels = []
    if not os.path.exists(label_path):
        print(f"⚠️ Label not found: {label_path}, skipping...")
        continue

    try:
        with open(label_path, "r") as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) != 5:
                    continue
                cls_id, x, y, w, h = map(float, parts)
                bboxes.append([x, y, w, h])
                class_labels.append(int(cls_id))
    except Exception as e:
        print(f"❌ Error reading label {label_path}: {e}")
        continue

    # Generate 8 augmented versions
    for i in range(8):
        augmented = transform(image=image, bboxes=bboxes, class_labels=class_labels)
        aug_image = augmented["image"]
        aug_bboxes = augmented["bboxes"]
        aug_classes = augmented["class_labels"]

        # Save image
        new_img_name = f"{base_name}_aug_{i}.jpg"
        cv2.imwrite(os.path.join(output_images, new_img_name), aug_image)

        # Save label
        new_label_name = f"{base_name}_aug_{i}.txt"
        with open(os.path.join(output_labels, new_label_name), "w") as f:
            for cls_id, bbox in zip(aug_classes, aug_bboxes):
                x, y, w, h = bbox
                f.write(f"{cls_id} {x:.6f} {y:.6f} {w:.6f} {h:.6f}\n")

print("✅ Done! Each image now has 8 augmented versions.")
print(f"Augmented images saved to: {output_images}")
print(f"Augmented labels saved to: {output_labels}")
# Out:
# Processing images: 100%|██████████| 14/14 [00:01<00:00,  8.94it/s]
# ✅ Done! Each image now has 8 augmented versions.
# Augmented images saved to: /content/data_train/balanced/images
# Augmented labels saved to: /content/data_train/balanced/labels

# %%
# !wget -O D:\yolo\train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# !python /content/D:yolotrain_val_split.py --datapath="/content/data_train/balanced" --train_pct=0.9
# Out:
# --2025-09-23 08:51:37--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘D:yolotrain_val_split.py’
#
# D:yolotrain_val_spl 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2025-09-23 08:51:37 (60.8 MB/s) - ‘D:yolotrain_val_split.py’ saved [3203/3203]
#
# Created folder at /content/data/train/images.
# Created folder at /content/data/train/labels.
# Created folder at /content/data/validation/images.
# Created folder at /content/data/validation/labels.
# Number of image files: 502
# Number of annotation files: 502
# Images moving to train: 451
# Images moving to validation: 51

# %%
import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': 'data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/data_train/classes.txt'
path_to_data_yaml = 'data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# Out:
# Created config file at data.yaml
#
# File contents:

# %%
# !yolo detect train data="/content/data/data.yaml" model=yolo11n.pt epochs=250 imgsz=640
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=250, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=12
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    433012  ultralytics.nn.modules.head.Detect           [12, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,592,180 parameters, 2,592,164 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3076.7±1201.8 MB/s, size: 1315.4 KB)
# train: Scanning /content/data/train/labels.cache... 451 images, 28 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 451/451 6.0Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 590.5±309.6 MB/s, size: 345.2 KB)
# val: Scanning /content/data/validation/labels.cache... 51 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 51/51 364.4Kit/s 0.0s
# Plotting labels to /content/runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000625, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train2
# Starting training for 250 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/250       2.3G      1.192      3.822      1.483         17        640: 100% ━━━━━━━━━━━━ 29/29 1.0it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 7.3s
#                    all         51         75     0.0415       0.82      0.138     0.0967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/250      2.68G     0.9973      3.378      1.343         26        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75     0.0106          1      0.218      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/250      2.69G     0.9945      2.954      1.356         14        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         51         75      0.687      0.102      0.313      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/250      2.69G       1.01      2.594      1.365         11        640: 100% ━━━━━━━━━━━━ 29/29 3.2it/s 9.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.556      0.392       0.41      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/250      2.69G      1.059      2.275      1.371         24        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.682      0.347      0.435      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/250      2.71G      1.035          2       1.34         21        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.334      0.716      0.614      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/250      2.72G     0.9812      1.886       1.32          9        640: 100% ━━━━━━━━━━━━ 29/29 2.5it/s 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.384      0.628      0.576      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/250      2.74G     0.9658      1.707      1.309          9        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         51         75      0.442      0.673      0.564      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/250      2.74G     0.9525      1.632      1.285          5        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         51         75       0.39      0.781      0.569      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/250      2.75G     0.9299      1.519      1.263         13        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         51         75      0.564      0.672      0.756      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/250      2.75G     0.9333      1.451      1.277          8        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         51         75      0.524      0.591      0.644      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/250      2.75G     0.9285      1.432       1.27          5        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         51         75      0.589      0.802      0.762      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/250      2.75G     0.9266      1.263      1.268         10        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 10.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         51         75       0.72      0.832      0.831       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/250      2.75G     0.8861       1.24      1.241         16        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         51         75      0.702      0.581       0.71      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/250      2.75G     0.8849      1.234      1.241         10        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75       0.71      0.845      0.886      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/250      2.75G     0.8384      1.147      1.191         16        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         51         75      0.568      0.732       0.73      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/250      2.75G     0.8531      1.116      1.202         19        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.854      0.824      0.912      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/250      2.75G     0.8325      1.178      1.209         22        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s
#                    all         51         75      0.867      0.866      0.903      0.683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/250      2.75G     0.8268      1.064      1.192          7        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         51         75      0.692      0.803      0.863      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/250      2.75G     0.8359      1.044      1.195         15        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         51         75      0.818      0.811      0.902      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/250      2.75G      0.792      1.042      1.179         22        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.826      0.742      0.845      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/250      2.75G     0.8044      1.028      1.178         18        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.886      0.855      0.935      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/250      2.75G     0.7846      1.007      1.166          6        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75       0.87      0.883      0.915      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/250      2.75G     0.7738      0.949      1.151          8        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75      0.932      0.885      0.935      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/250      2.75G     0.7781     0.9434      1.158         12        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         51         75      0.848      0.883      0.929      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/250      2.75G     0.7721     0.9193      1.158          8        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s
#                    all         51         75      0.905      0.819      0.931      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/250      2.75G      0.751     0.8692      1.139         11        640: 100% ━━━━━━━━━━━━ 29/29 3.3it/s 8.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         51         75      0.788      0.876       0.93      0.744
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/250      2.75G     0.7598     0.8686      1.149         10        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.831       0.82       0.92       0.74
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/250      2.75G     0.7312     0.8736      1.142          9        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         51         75      0.882      0.885      0.929      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/250      2.75G     0.7461      0.868      1.134         13        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75      0.837      0.922       0.94      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/250      2.75G      0.727     0.8616      1.135         24        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.892      0.854      0.924       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/250      2.75G      0.769     0.8941      1.164          5        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75       0.72      0.827      0.925      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/250      2.75G     0.7398     0.8213      1.133          9        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75      0.932      0.877      0.932      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/250      2.75G     0.7299      0.781      1.122         19        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         51         75      0.909      0.874      0.925      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/250      2.75G     0.7377     0.7914      1.126         13        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         51         75      0.818      0.847      0.887      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/250      2.75G      0.756     0.8253      1.144         15        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75      0.848      0.764      0.897      0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/250      2.75G     0.6915     0.7779      1.101         13        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         51         75      0.871      0.833      0.906      0.777
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/250      2.75G     0.6849     0.7831      1.084         18        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.788      0.852      0.897      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/250      2.75G     0.7058     0.7752       1.11         22        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s
#                    all         51         75      0.859      0.796      0.871      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/250      2.75G     0.7191      0.763      1.112         13        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75      0.867      0.851      0.946      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/250      2.75G     0.7137     0.7694      1.103         14        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         51         75      0.876      0.887      0.922      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/250      2.76G      0.715     0.7793      1.117         16        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         51         75      0.868      0.804      0.912      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/250      2.76G     0.6907      0.739       1.09         21        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75      0.874      0.802      0.926       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/250      2.76G     0.6825     0.7128      1.086          8        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75      0.897      0.902      0.942      0.792
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/250      2.76G     0.6742     0.7549      1.099         11        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         51         75      0.905      0.849      0.918      0.764
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/250      2.76G     0.6636     0.7112      1.075         25        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         51         75      0.872       0.88      0.928      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/250      2.76G     0.6701     0.7248      1.084         10        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.887      0.891       0.95      0.819
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/250      2.76G     0.6591     0.6973      1.091         17        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.7it/s 0.7s
#                    all         51         75       0.91      0.901      0.934      0.789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/250      2.76G     0.6464     0.6678      1.074         11        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         51         75      0.903      0.872       0.91      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/250      2.76G     0.6348     0.6618      1.068         12        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75      0.827      0.843      0.938      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/250      2.76G     0.6329     0.6581      1.075          7        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.7s
#                    all         51         75      0.902      0.861      0.955      0.813
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/250      2.76G     0.6477     0.6848      1.081          9        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         51         75      0.925      0.849      0.965      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/250      2.76G     0.6754     0.6665      1.074         10        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         51         75      0.896      0.911       0.97       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/250      2.76G     0.6287     0.6326      1.049         33        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.841      0.923      0.968      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/250      2.76G      0.634     0.6456      1.073         26        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s
#                    all         51         75      0.932      0.899      0.944      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/250      2.76G     0.6121     0.6567       1.06          5        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         51         75      0.911      0.875      0.925      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/250      2.76G     0.6283     0.6466      1.074         34        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75       0.83      0.942      0.943      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/250      2.76G     0.6225     0.6081      1.056         18        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.892      0.836      0.938      0.802
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/250      2.76G     0.6077     0.6462      1.066          8        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.912      0.853      0.938      0.813
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/250      2.76G     0.6516     0.6422      1.094          8        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75      0.895      0.895      0.935      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/250      2.76G     0.6024     0.6259       1.06         14        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         51         75      0.897      0.825      0.906      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/250      2.76G     0.6083     0.5988      1.044         22        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75      0.923      0.865      0.933      0.806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/250      2.76G     0.5855     0.5977      1.049         16        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         51         75      0.897      0.891      0.925      0.794
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/250      2.76G     0.5923     0.5934      1.042          6        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         51         75      0.914      0.886      0.959      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/250      2.76G     0.5989     0.5809      1.037         17        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         51         75      0.886       0.91      0.927      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/250      2.76G     0.5802     0.5904      1.036         19        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         51         75      0.922      0.901      0.937      0.799
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/250      2.76G      0.591     0.5897      1.053         16        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.922      0.931      0.966      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/250      2.76G     0.5878     0.5893      1.044         11        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.7s
#                    all         51         75       0.92      0.895      0.975      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/250      2.76G     0.5664      0.571      1.027         13        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         51         75      0.903       0.79      0.948      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/250      2.76G     0.5882     0.5853      1.038         15        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         51         75      0.923      0.866      0.953      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/250      2.76G     0.5944     0.5507      1.051          8        640: 100% ━━━━━━━━━━━━ 29/29 3.4it/s 8.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.9it/s 1.0s
#                    all         51         75      0.933       0.88      0.946      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/250      2.76G     0.5627     0.5464      1.018         13        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         51         75      0.914      0.873      0.943      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/250      2.76G     0.5587     0.5429      1.018         18        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s
#                    all         51         75      0.927        0.9      0.948      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/250      2.76G     0.5524     0.5464      1.018         15        640: 100% ━━━━━━━━━━━━ 29/29 2.5it/s 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         51         75      0.895      0.927      0.973      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/250      2.76G     0.5798     0.5761      1.047         15        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s
#                    all         51         75      0.937        0.9      0.985       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/250      2.76G     0.5643     0.5561      1.039          5        640: 100% ━━━━━━━━━━━━ 29/29 2.4it/s 11.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         51         75      0.936       0.94      0.974       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/250      2.76G     0.5564     0.5592      1.027          7        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.942      0.904      0.965       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/250      2.76G     0.5401     0.5311      1.013         10        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         51         75      0.928      0.886      0.943      0.837
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/250      2.76G     0.5519     0.5265      1.015         10        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         51         75       0.91      0.907      0.939      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/250      2.77G     0.5303     0.5255      1.009         12        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         51         75      0.934      0.925      0.974      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/250      2.77G     0.5209     0.5117      1.005         12        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.4it/s 0.5s
#                    all         51         75      0.939      0.884      0.949      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/250      2.77G      0.548     0.5237      1.018         18        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.936        0.9       0.93      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/250      2.77G     0.5307     0.5069      1.007         13        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s
#                    all         51         75      0.926      0.904       0.94      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/250      2.77G     0.5201     0.5146      1.018          8        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.881      0.894      0.935      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/250      2.77G     0.5203     0.5112      1.013         11        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75      0.962      0.861      0.937      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/250      2.77G     0.5334     0.5596      1.009          4        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         51         75      0.941      0.908      0.964      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/250      2.77G     0.5364     0.5067      1.027         13        640: 100% ━━━━━━━━━━━━ 29/29 3.3it/s 8.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         51         75      0.942      0.909      0.968      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/250      2.77G     0.5315     0.5069      1.023          7        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s
#                    all         51         75       0.92      0.932       0.97      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/250      2.77G     0.5163     0.4829      0.992         24        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.9it/s 0.5s
#                    all         51         75      0.887      0.916      0.963      0.837
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/250      2.77G     0.5143     0.5067      1.004          7        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.939      0.907      0.951      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/250      2.77G      0.513      0.504      1.008         17        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.935      0.894      0.946      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/250      2.77G      0.517     0.4965      1.006          8        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.933      0.846      0.907      0.815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/250      2.77G     0.5171      0.504      1.037          5        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 10.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         51         75      0.947      0.889      0.918      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/250      2.77G     0.4932     0.4832     0.9962         17        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         51         75       0.94      0.921      0.964      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/250      2.77G      0.489     0.4954     0.9953          4        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.941      0.913      0.951      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/250      2.77G     0.4973     0.4645     0.9968          5        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.917      0.898      0.944      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/250      2.77G      0.486     0.4591     0.9919         15        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.925      0.909      0.941      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/250      2.77G     0.5064     0.4985     0.9968         10        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75       0.93      0.867      0.942      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/250      2.77G      0.484     0.4801     0.9973          5        640: 100% ━━━━━━━━━━━━ 29/29 2.5it/s 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         51         75      0.892      0.898      0.955      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/250      2.77G     0.4945     0.4798     0.9973          9        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75      0.906      0.904      0.946       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     101/250      2.77G     0.4926     0.4758     0.9955          9        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         51         75      0.935      0.891      0.961      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     102/250      2.77G     0.4826      0.451     0.9855          9        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         51         75      0.933      0.884      0.974      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     103/250      2.77G      0.477     0.4638     0.9816         15        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.0it/s 1.0s
#                    all         51         75      0.929      0.916       0.97      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     218/250      2.77G     0.2912      0.275     0.9081         14        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         51         75      0.942      0.912      0.963      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     219/250      2.77G     0.2932     0.2672     0.9005         18        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s
#                    all         51         75      0.945       0.91       0.97       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     220/250      2.77G     0.2965     0.2716     0.8966          7        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s
#                    all         51         75      0.945      0.908      0.969      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     221/250      2.77G     0.3046      0.289     0.9089         17        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.8it/s 0.5s
#                    all         51         75      0.939      0.908      0.962      0.917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     222/250      2.77G     0.2981     0.2789     0.8942         14        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.935      0.916       0.97      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     223/250      2.77G      0.303     0.2744     0.9133         15        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8it/s 0.7s
#                    all         51         75      0.939      0.917      0.972       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     224/250      2.77G     0.2997     0.2821     0.8943         33        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.3it/s 0.9s
#                    all         51         75       0.95      0.909      0.968      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     225/250      2.77G     0.2946     0.2861     0.8937         11        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.6it/s 0.8s
#                    all         51         75      0.952      0.909      0.965       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     226/250      2.77G      0.293      0.272     0.8958         10        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75      0.954      0.911      0.972      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     227/250      2.77G     0.2867     0.2746     0.8995         15        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75      0.953       0.91       0.97      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     228/250      2.77G     0.2913     0.2746     0.8997         14        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.0it/s 0.5s
#                    all         51         75      0.942      0.907      0.965      0.904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     229/250      2.77G     0.2893     0.2799     0.9018         12        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.3it/s 0.5s
#                    all         51         75      0.958      0.893      0.958      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     230/250      2.77G     0.2846     0.2696     0.8975         15        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2it/s 0.6s
#                    all         51         75      0.957      0.899      0.965      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     231/250      2.77G     0.3017     0.2752     0.8969         18        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75      0.944      0.908      0.966      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     232/250      2.77G     0.2941     0.2735     0.9118          8        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         51         75       0.95      0.909      0.965      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     233/250      2.77G     0.2876     0.2834     0.8983         14        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         51         75      0.949      0.906       0.96      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     234/250      2.77G     0.2818     0.2741     0.8976          7        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.4it/s 0.6s
#                    all         51         75       0.95      0.906       0.96      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     235/250      2.77G     0.2758      0.271     0.8857         11        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.7it/s 0.5s
#                    all         51         75       0.95      0.907      0.972      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     236/250      2.77G     0.2934     0.2782     0.8993         12        640: 100% ━━━━━━━━━━━━ 29/29 2.5it/s 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.5s
#                    all         51         75      0.949      0.909       0.97       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     237/250      2.77G     0.2895     0.2649     0.8921         24        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0it/s 0.7s
#                    all         51         75      0.947      0.906      0.967      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     238/250      2.77G     0.2737     0.2715     0.8922         19        640: 100% ━━━━━━━━━━━━ 29/29 2.5it/s 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9it/s 0.7s
#                    all         51         75      0.948      0.906      0.962      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     239/250      2.77G     0.2742     0.2592     0.8973         12        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.1it/s 0.5s
#                    all         51         75      0.949      0.906      0.958      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     240/250      2.77G     0.2797     0.2734     0.9045          8        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5it/s 0.8s
#                    all         51         75      0.947      0.903      0.967      0.911
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     241/250      2.77G     0.2862     0.2688     0.9017         11        640: 100% ━━━━━━━━━━━━ 29/29 2.3it/s 12.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75      0.951      0.906      0.954      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     242/250      2.77G     0.2814     0.2547      0.892          5        640: 100% ━━━━━━━━━━━━ 29/29 3.0it/s 9.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 1.0s
#                    all         51         75       0.95      0.905      0.952      0.896
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     243/250      2.77G     0.2704     0.2588     0.8883          2        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         51         75      0.948      0.904      0.939      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     244/250      2.77G     0.2502     0.2321     0.8822          9        640: 100% ━━━━━━━━━━━━ 29/29 3.2it/s 9.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75      0.954      0.906      0.942      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     245/250      2.77G     0.2511     0.2247     0.8844          3        640: 100% ━━━━━━━━━━━━ 29/29 2.6it/s 11.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75      0.955      0.906      0.944      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     246/250      2.77G      0.239     0.2233     0.8656          6        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         51         75      0.956      0.906      0.944      0.896
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     247/250      2.77G     0.2375     0.2195     0.8647          3        640: 100% ━━━━━━━━━━━━ 29/29 2.7it/s 10.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.3it/s 0.6s
#                    all         51         75      0.953      0.906      0.946      0.896
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     248/250      2.77G     0.2462     0.2288     0.8843          5        640: 100% ━━━━━━━━━━━━ 29/29 2.8it/s 10.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.1it/s 0.6s
#                    all         51         75      0.953      0.905      0.955      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     249/250      2.77G     0.2332     0.2117     0.8721          3        640: 100% ━━━━━━━━━━━━ 29/29 2.9it/s 9.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s
#                    all         51         75      0.957      0.905      0.958      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     250/250      2.77G       0.23     0.2201     0.8679          3        640: 100% ━━━━━━━━━━━━ 29/29 3.1it/s 9.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.1it/s 0.9s
#                    all         51         75      0.953      0.905      0.959      0.903
#
# 250 epochs completed in 0.879 hours.
# Optimizer stripped from /content/runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,584,492 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.6it/s 0.6s
#                    all         51         75      0.944      0.907      0.972      0.922
#   ١٤ % رواد بياض دواجن          3          3      0.963          1      0.995      0.995
#  ١٤ % رواد تسمين مواشي          4          4      0.985          1      0.995      0.995
#   ١٦ % رواد حلاب مواشي          1          1      0.914          1      0.995      0.995
#   ١٦ % رواد بياض دواجن         11         11      0.992      0.909      0.981      0.937
#  ١٦ % رواد تسمين مواشي          4          4      0.971          1      0.995      0.995
# ١٩ % رواد حلاب عالي الإدِرار مواشي          4          4      0.974       0.75      0.912      0.802
#   ١٩ % رواد سوبر دواجن          8          8      0.851          1      0.995      0.932
# ٢٠ % رواد فطام بتلو مواشي          7          7      0.871          1      0.995      0.896
#   ٢١ % رواد سوبر دواجن          9         13          1      0.989      0.995      0.968
# ٢١ % رواد بادي نامي محبب دواجن          5          5          1      0.539      0.866      0.748
# ٢١ % رواد بادي نامي مفتت دواجن          4          6          1      0.699      0.972      0.903
#   ٢٣ % رواد سوبر دواجن          8          9      0.809          1      0.973      0.893
# Speed: 0.2ms preprocess, 2.8ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo detect predict model=runs/detect/train2/weights/best.pt source=data/validation/images save=True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 960, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 83, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 153, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 297, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1501, in load_checkpoint
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1448, in torch_safe_load
#     ckpt = torch_load(file, map_location="cpu")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/patches.py", line 120, in torch_load
#     return torch.load(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1484, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 759, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 740, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/detect/train2/weights/best.pt'

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.203-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.203 ultralytics-thop-2.0.17
